# %% [markdown]
# <a href="https://colab.research.google.com/github/tysud/PHYS486-S22/blob/main/ProjectOne/ProjectOneprojectcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import packages that we'll use often; 
#use conventional names (i.e., numpy as np, etc.).
import numpy as np
import math

#import matplotlib packages we'll use frequently;
#again use conventional names (pyplot as plt, colorbar as cb, etc.)
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.colorbar as cb

#tell the notebook we want a copy of the figure inline
# %matplotlib inline

#set preferences to make our plots cleaner / more legible
from IPython.display import set_matplotlib_formats
#set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 200
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 8,8
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.linewidth'] = 2
#plt.rcParams['axes.tickwidth'] = 8

plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

# %%
# Defining physical constants

float C = 1 # Drag coeefficient
float A = 1 # Cross-sectional area
float rho = 1 # density of medium (air density)
float m = 1 # mass of projectile
gamma = (C*A*rho)/(2*m) # combine constants
float g = 9.8 #acceleration due to gravity

# Defining initial conditions

float v_0 = 0 # initial velocity (magnitude in 2D)
float theta = 0 # launch angle (from horizontal)
float h_0 = 0 # initial height

time_step = 0.1 #time step for iterations



# Functions for updating velocities

def UpdateVelocityX(v_x_now, t_step):
  # Calculating next step for x-velocities
  dv_x_dt = -gamma*(v_x_now)**2
  v_x_next = v_x_now + dv_x_dt*t_step
  return v_x_next

def UpdateVelocityY(v_y_now, t_step):
  # Calculating next step for y-velocities
  dv_y_dt = g - gamma*(v_y_now)**2
  v_y_next = v_y_now + dv_y_dt*t_step
  return v_y_next

# Function for creating the list of velocities and times

def CalculateVelocity(h_0, v_0, theta, t_step):
  # Calculating the components of velocity
  v_x_0 = v_0*math.cos((180/3.14159)theta)
  v_y_0 = v_0*math.sin((180/3.14159)theta)


  for n in range():
    times[n+1] = times[n] + t_step
    v_x[n+1] = UpdateVelocityX(v_x[n], t_step)
    v_y[n+1] = UpdateVelocityY(v_y[n], t_step)

  return times, v_x, v_y


# Function for calculating positions from velocities

def CalculatePosition(h_0, v_x, v_y, times):




  return times, x, y
